# %% [markdown]
# # 📑 Practice Questions

# %% [markdown]
# ## ✅ When to use Z-test?
#
# Use Z-test when:
#    1. Population standard deviation (σ) is known
#    2. Sample size is large (n ≥ 30)
#    3. Data is approximately normal
#
# **Short exam line:**
# Z-test is used when population standard deviation is known and sample size is large.

# %% [markdown]
# ## ✅ Difference between one-tailed and Two-tailed Z-test
#
# **One-tailed**
#   - Checks only ONE direction
#   - Greater than OR less than
#
# Example: Mean > 4
#
# ---
#
# Two-tailed
#   - Checke BOTH directions
#   - Not equal
#
# Example: Mean ≠ 24

# %% [markdown]
# ## ✅ Difference between One-sample and Two-sample Z-test
# **One-sample**
# compare sample mean with population mean.
#
# **two-sample**
# Compare means of TWO populations.
#
# 📌 MINI ASSIGNMENT
#
# 🧪 Question 1 - One Sample Z-test (Two-Tailed)
#
# 📘 Scenario
#
# A smartphone manufacturer claims that the average battery backup of its phone is 24 hours.
#
# A random sample of 36 phones gives:
#
# • Sample mean = 23.4 hours
#
# • Population standard deviation (σ) = 2 hours
#
# Test the claim at α = 0.05.
#
# 📝 Tasks
# 1. State H₀ and H₁
# 2. Calculate z-score manually
# 3. Compute p-value
# 4. Find critical z-value
# 5. Make a decision using:
#
#     • Method-1 (p-value)
#
#     • Method-2 (critical value)
# 6. Write final interpretation in plain English
#
# Given
# - μ = 24
# - x̄ = 23.4
# - σ = 2
# - n = 36
# - α = 0.05

# %% [markdown]
# **step-1 Hypotheses**
# H₀: μ = 24
# H₁: μ ≠ 24

# %% [markdown]
# **Step-2 Z-score (manual)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Step-3 p-value (two-tailed)**
#
# p ≈ 0.071

# %% [markdown]
# **Step-4 Critical Z**
#
# α = 0.05 -> two-tailed
#
# Zcritical = ±1.96
